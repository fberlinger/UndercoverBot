# %% [markdown]
# # Experiment: Aggregation & Dispersion
# The goal is to reach a point evenly dispersered from both a too close and too far starting point

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import matplotlib

matplotlib.rcParams['figure.figsize'] = [12, 8]

import math
import numpy as np

from interaction import Interaction
from environment import Environment
from DelightFish import Fish
from channel import Channel
from observer import Observer

from utils import generate_distortion, generate_fish, generate_replica_fish, generate_all_fish, run_simulation
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Experiment: Dispersion

# %%
run_time = 30 # in seconds
num_fish = 30
num_replica_fish = 0
arena_size = 30
arena_center = arena_size / 2.0
initial_spread = 1
fish_pos = initial_spread * np.random.rand(num_fish + num_replica_fish, 2) + arena_center - initial_spread / 2.0
clock_freqs = 1
verbose = False

distortion = generate_distortion(type='none', n=arena_size)
environment = Environment(
    node_pos=fish_pos,
    distortion=distortion,
    prob_type='binary',
    noise_magnitude=0,
    conn_thres=6,
    verbose=verbose
)
interaction = Interaction(environment, verbose=verbose)
channel = Channel(environment)

fish = generate_all_fish(
    n_fish=num_fish,
    n_replica_fish= num_replica_fish,
    channel=channel, 
    interaction=interaction,
    k_coh = 0,
    k_ar = 0.01,
    alpha = 3,
    lim_neighbors=[0, math.inf],
    neighbor_weights=1.0,
    fish_max_speeds=1,
    clock_freqs=clock_freqs,
    verbose=verbose
)
channel.set_nodes(fish)

observer = Observer(fish=fish, environment=environment, channel=channel)
run_simulation(fish=fish, observer=observer, run_time=run_time, dark=True, white_axis=False, no_legend=True, no_star=False, show_dist_plot=True)
# Out:
# Please wait patiently 30 seconds. Thanks.
# It's time to say bye bye!

# %% [markdown]
# ## Experiment: Aggregation

# %%
run_time = 30 # in seconds
num_fish = 30
num_replica_fish = 0
arena_size = 30
arena_center = arena_size / 2.0
initial_spread = 4
fish_pos = initial_spread * np.random.rand(num_fish + num_replica_fish, 2) + arena_center - initial_spread / 2.0
clock_freqs = 1
verbose = False

distortion = generate_distortion(type='none', n=arena_size)
environment = Environment(
    node_pos=fish_pos,
    distortion=distortion,
    prob_type='binary',
    noise_magnitude=0,
    conn_thres=6,
    verbose=verbose
)
interaction = Interaction(environment, verbose=verbose)
channel = Channel(environment)

fish = generate_all_fish(
    n_fish=num_fish,
    n_replica_fish= num_replica_fish,
    channel=channel, 
    interaction=interaction,
    k_coh = 0,
    k_ar = 0.03,
    alpha = 1,
    lim_neighbors=[0, math.inf],
    neighbor_weights=1.0,
    fish_max_speeds=1,
    clock_freqs=clock_freqs,
    verbose=verbose
)
channel.set_nodes(fish)

observer = Observer(fish=fish, environment=environment, channel=channel)
run_simulation(fish=fish, observer=observer, run_time=run_time, dark=True, white_axis=False, no_legend=True, no_star=False, show_dist_plot=True)
# Out:
# Please wait patiently 30 seconds. Thanks.
# It's time to say bye bye!

# %% [markdown]
# ## Aggregate from far away, final dist ~2.6

# %%
run_time = 30 # in seconds
num_fish = 30
num_replica_fish = 0
arena_size = 100
arena_center = arena_size / 2.0
initial_spread = 10
fish_pos = initial_spread * np.random.rand(num_fish + num_replica_fish, 2) + arena_center - initial_spread / 2.0
clock_freqs = 1
verbose = False

distortion = generate_distortion(type='none', n=arena_size)
environment = Environment(
    node_pos=fish_pos,
    distortion=distortion,
    prob_type='binary',
    noise_magnitude=0,
    conn_thres=6,
    verbose=verbose
)
interaction = Interaction(environment, verbose=verbose)
channel = Channel(environment)

fish = generate_all_fish(
    n_fish=num_fish,
    n_replica_fish= num_replica_fish,
    channel=channel, 
    interaction=interaction,
    k_coh = 0,
    k_ar = 0.03,
    alpha = 3,
    lim_neighbors=[0, math.inf],
    neighbor_weights=1.0,
    fish_max_speeds=1,
    clock_freqs=clock_freqs,
    verbose=verbose
)
channel.set_nodes(fish)

observer = Observer(fish=fish, environment=environment, channel=channel)
run_simulation(fish=fish, observer=observer, run_time=run_time, dark=True, white_axis=False, no_legend=True, no_star=False, show_dist_plot=True)
# Out:
# Please wait patiently 30 seconds. Thanks.

# %% [markdown]
# ## Disperse to far away, final dist ~ 4.

# %%
run_time = 30 # in seconds
num_fish = 30
num_replica_fish = 0
arena_size = 1000
arena_center = arena_size / 2.0
initial_spread = 2
fish_pos = initial_spread * np.random.rand(num_fish + num_replica_fish, 2) + arena_center - initial_spread / 2.0
clock_freqs = 1
verbose = False

distortion = generate_distortion(type='none', n=arena_size)
environment = Environment(
    node_pos=fish_pos,
    distortion=distortion,
    prob_type='binary',
    noise_magnitude=0,
    conn_thres=6,
    verbose=verbose
)
interaction = Interaction(environment, verbose=verbose)
channel = Channel(environment)

fish = generate_all_fish(
    n_fish=num_fish,
    n_replica_fish= num_replica_fish,
    channel=channel, 
    interaction=interaction,
    k_coh = 0,
    k_ar = 0.03,
    alpha = 3.5,
    lim_neighbors=[0, math.inf],
    neighbor_weights=1.0,
    fish_max_speeds=1,
    clock_freqs=clock_freqs,
    verbose=verbose
)
channel.set_nodes(fish)

observer = Observer(fish=fish, environment=environment, channel=channel)
run_simulation(fish=fish, observer=observer, run_time=run_time, dark=True, white_axis=False, no_legend=True, no_star=False, show_dist_plot=True)
# Out:
# Please wait patiently 30 seconds. Thanks.
# It's time to say bye bye!
# It's time to say bye bye!
# It's time to say bye bye!
# It's time to say bye bye!
